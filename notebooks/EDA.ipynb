# %%
import plotly.express as px
import pandas as pd 

car_data = pd.read_csv('~/proyecto5/vehicles_env/AVAMS/vehicles_us.csv')
fig = px.bar(car_data, x='odometer')
fig.show()

# %%
import pandas as pd 
import plotly.express as px


car_data = pd.read_csv('~/proyecto5/vehicles_env/AVAMS/vehicles_us.csv')

table = car_data.pivot_table(index='model',columns='condition', values='model_year')
print(table)
fig2 = px.histogram(table)
fig2.show()
# Out:
# condition            excellent         fair         good     like new     new  \
# model
# acura tl           2008.715686  2002.875000  2006.582418  2007.521739     NaN
# bmw x5             2009.837838  2004.000000  2007.029412  2009.642857     NaN
# buick enclave      2012.189189  2011.000000  2011.703704  2013.740741     NaN
# cadillac escalade  2008.710526  2003.500000  2007.382353  2011.771429     NaN
# chevrolet camaro   2010.502304  1992.142857  2003.778846  2011.627119  1997.8
# ...                        ...          ...          ...          ...     ...
# toyota sienna      2009.928571  2004.363636  2007.038462  2010.461538  2019.0
# toyota tacoma      2010.536000  2003.210526  2006.961404  2013.273810  2013.0
# toyota tundra      2011.079310  2004.105263  2006.830189  2012.069767     NaN
# volkswagen jetta   2011.812766  2005.315789  2009.157303  2013.603774     NaN
# volkswagen passat  2012.354839  2005.545455  2009.750000  2011.656250  2008.5
#
# ...

# %%
import pandas as pd 
import plotly.express as px


car_data = pd.read_csv('~/proyecto5/vehicles_env/AVAMS/vehicles_us.csv')

table = car_data.pivot_table(index='model_year',columns='condition', values='price')

fig2 = px.scatter(table)
fig2.show()
# Out:
# condition      excellent          fair          good      like new  \
# model_year
# 1908.0      12995.000000           NaN  12995.000000           NaN
# 1929.0               NaN           NaN  18000.000000           NaN
# 1936.0       5000.000000           NaN           NaN           NaN
# 1948.0               NaN           NaN           NaN  21000.000000
# 1949.0               NaN           NaN  44900.000000           NaN
# ...                  ...           ...           ...           ...
# 2015.0      17595.995673  10485.714286  19415.398482  19633.012255
# 2016.0      18476.907589  15298.666667  20825.016746  21047.300847
# 2017.0      19381.316679  11800.000000  22504.642089  22320.242826
# 2018.0      21732.962822  15200.000000  26436.366412  26976.954628
# 2019.0      24790.250000           NaN  25057.950000  29257.734043
#
# condition            new       salvage
# model_year
# 1908.0               NaN           NaN
# 1929.0               NaN           NaN
# ...

# %%
car_data
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1      25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
# ...
